# %% [markdown]
# # <font color="#ff4500" style="font-size: 30px;">Código Python Todo Dia</font>

# %% [markdown]
# <hr style="border: 2px solid #4500ff;">
#
# # <font color="#4500ff" style="font-size: 25px;">Exercício 147</font>
# <hr style="border: 2px solid #4500ff;">
#
#  <p style='font-size: 23px; line-height: 2; margin: 0px 0px; text-align: justify; text-indent: 0px;'>
# <i><b> Crie uma classe Pessoa com os seguintes atributos: nome, sobrenome e idade.
# </b></i>
# </p>
#
# ---

# %%
class Pessoa:
    def __init__(self, nome:str, sobrenome: str, idade: int):
        self.nome = nome
        self.sobrenome = sobrenome
        self.idade = idade

# %% [markdown]
# <hr style="border: 2px solid #4500ff;">
#
# # <font color="#4500ff" style="font-size: 25px;">Exercício 148</font>
# <hr style="border: 2px solid #4500ff;">
#
#  <p style='font-size: 23px; line-height: 2; margin: 0px 0px; text-align: justify; text-indent: 0px;'>
# <i><b> Acrescente a classe Pessoa um método para mostrar os dados de uma pessoa. Crie um objeto do tipo Pessoa para testar suas propriedades e métodos.
# </b></i>
# </p>
#
# ---

# %%
class Pessoa:
    def __init__(self, nome, sobrenome, idade):
        self.nome = nome
        self.sobrenome = sobrenome
        self.idade = idade
        
    def mostrar_Dados(self):
        print(self.nome, self.sobrenome, "---", self.idade)
        
    
eu = Pessoa("Miguel", "Freire", 24)
eu.mostrar_Dados()
print(eu.nome)
print(eu.idade)
# Out:
# Miguel Freire --- 24
# Miguel
# 24

# %% [markdown]
# <hr style="border: 2px solid #4500ff;">
#
# # <font color="#4500ff" style="font-size: 25px;">Exercício 149</font>
# <hr style="border: 2px solid #4500ff;">
#
#  <p style='font-size: 23px; line-height: 2; margin: 0px 0px; text-align: justify; text-indent: 0px;'>
# <i><b> Crie uma classe Pessoa com as seguintes características:
#
# ## Atributos:
#
# ### - Nome (atributo público);
#
# ### - E-mail (atributo público);
#
# ### - Senha (atributo privado).
#
# ## Métodos:
#
# ### - Mostrar nome;
#
# ### - Mostrar E-mail;
#
# ### - Mostrar senha.
#
#
#
# ## Crie um objeto da classe Pessoa para testar suas propriedades e métodos.
# </b></i>
# </p>
#
# ---

# %%
class Pessoa:
    def __init__(self, nome, email, senha):
        self.nome = nome
        self.email = email
        self.__senha = senha  

    def mostrar_dados(self):
        print(self.nome, self.email, "---", self.__senha)

eu = Pessoa("Miguel", "freire@email.com", "123456")
eu.mostrar_dados()
print(eu.nome)
# print(eu.senha)  # da erro

print()

class Pessoa:
    
    def __init__(self,nome,email,senha):
        self.nome=nome
        self.email=email
        self.__senha=senha
    
    def mostrar_senha(self):
        return self.__senha
    
    def mostrar_nome(self):
        return self.nome
    
    def mostrar_email(self):
        return self.email
    
    
user=Pessoa('User','user@email.com','x54a_Zkp79c')
print()
print(f'Nome: {user.mostrar_nome()}')
print(f'E-mail: {user.mostrar_email()}')
print(f'Senha: {user.mostrar_senha()}')
# Out:
# Miguel freire@email.com --- 123456
# Miguel
#
#
# Nome: User
# E-mail: user@email.com
# Senha: x54a_Zkp79c

# %% [markdown]
# <div style="text-align: center;">
#     <hr style="border: 2px solid #4500ff;">
#     <font color="#4500ff" style="font-size: 25px;"><b>Exercício 150</b></font>
#     <hr style="border: 2px solid #4500ff;">
#     <p style='font-size: 23px; line-height: 2; text-align: justify;  margin-bottom: 25px;'>
#             <i><b> Crie uma classe Pessoa com as seguintes características:</b></i>
#         </p>
# </div>
# <div style="display: flex; justify-content: space-between;">
#     <div style="width: 45%;">
#         <p style='font-size: 23px; line-height: 2; text-align: justify;'>
#             <i><b> __Atributos__:
#             <br>
#              - Nome;
#             <br>
#              - Estoque;
#             <br>
#              - Descrição;
#             <br>
#              - Preço.
#             </b></i>
#         </p>
#     </div>
#     <div style="width: 45%;">
#         <p style='font-size: 20px; line-height: 2; text-align: justify;'>
#             <i><b>  __Métodos__:
#             <br>
#              - Mostrar nome;
#             <br>
#              - Mostrar estoque;
#             <br>
#              - Mostrar preço;
#             <br>
#              - Mudar nome;
#             <br>
#              - Mudar estoque;
#             <br>
#              - Mudar descrição;
#             <br>
#              - Mudar preço;
#             <br>
#              - Sumário (mostrar na tela todos os atributos de instância).
#             </b></i>
#         </p>
#     </div>
# </div>

# %%
class Pessoa:
    
    def __init__(self,nome,estoque,descricao,preco):
        self.nome=nome
        self.estoque=estoque
        self.descricao=descricao
        self.preco=preco

    
    def mostrar_estoque(self):
        return self.estoque
    
    def mostrar_nome(self):
        return self.nome
    
    def mostrar_preco(self):
        return self.preco
    
    
    def mudar_estoque(self, estoque_novo):
        self.estoque = estoque_novo
    
    def mudar_nome(self, nome_novo):
        self.nome = nome_novo
    
    def mudar_preco(self, preco_novo):
        self.preco = preco_novo
    
    def mudar_descricao(self, descricao_novo):
        self.descricao = descricao_novo
        
    def sumario(self):
        print("-"*len("Sumário do produto"), "\nSumário do produto\n"+"-"*len("Sumário do produto"))
        print("Nome -->", self.nome)
        print("Estoque -->", self.estoque)
        print("Preco -->", self.preco)
        print("Descrição -->", self.descricao)

# %%
    
    
eu = Pessoa("Laranja", 20, "Laranja docinha", 3.50)

print(f"{eu.mostrar_estoque()}")
print(f"{eu.mostrar_nome()}")
print(f"{eu.mostrar_preco()}")


print()


eu.mudar_descricao('laranja Legal!')
eu.mudar_estoque(25)
eu.mudar_preco(2.50)
eu.mudar_nome('Laranja (a top)')

eu.sumario()
# Out:
# 20
# Laranja
# 3.5
#
# ------------------
# Sumário do produto
# ------------------
# Nome --> Laranja (a top)
# Estoque --> 25
# Preco --> 2.5
# Descrição --> laranja Legal!

# %% [markdown]
# <hr style="border: 2px solid #4500ff;">
#
# # <font color="#4500ff" style="font-size: 25px;">Exercício 151</font>
# <hr style="border: 2px solid #4500ff;">
#
#  <p style='font-size: 23px; line-height: 2; margin: 0px 0px; text-align: justify; text-indent: 0px;'>
# <i><b> Crie uma classe Lampada com os seguintes atributos e métodos:
#
# ## Atributos:
#
# ### - Cor
#
# ### - Voltagem
#
# ### - Ligada (a lâmpada deve inicializar desligada)
#
# ## Métodos:
#
# ### - Verificar se a lâmpada está ligada/desligada;
#
# ### - Ligar/desligar a lâmpada
#
# ### - Todos os atributos devem ser privados.
#
#
#
# ## crie um objeto da classe Lampada e teste os métodos criados.
# </b></i>
# </p>
#
# ---

# %%
class Lampada:
    def __init__(self, cor, voltagem, luminosidade):
        self.__cor = cor
        self.__voltagem = voltagem
        self.__luminosidade = luminosidade
        self.__ligada = 0
        
    def verificar_ligada(self):
        if self.__ligada == 0:
            return "Desligada"
        else:
            print("Ligada")
    
    def ligar_desligar(self):
        if self.__ligada == 0:
            self.__ligada = 1
            return "lampada ligada"
        if self.__ligada == 1:
            self.__ligada = 0
            return "lampada desligada"
        
lamp1=Lampada('azul',110,80)
print(lamp1.verificar_ligada())  #Inicializa desligada
print(lamp1.ligar_desligar())  #Ligada
print(lamp1.ligar_desligar())  #Desligada
print()

        
#outra forma de resolver


class Lampada:
    
    def __init__(self,cor,voltagem,luminosidade):
        self.__cor=cor
        self.__voltagem=voltagem
        self.__luminosidade=luminosidade
        self.__ligada=False
    
    def verificar_ligada(self):
        return self.__ligada
 
    def ligar_desligar(self):
        if self.__ligada:
            self.__ligada=False
            print("teste", self.__ligada)
            return self.__ligada
        else:
            self.__ligada=True
            return self.__ligada
            
lamp1=Lampada('azul',110,80)
print(lamp1.verificar_ligada())  #Inicializa desligada
print(lamp1.ligar_desligar())  #Ligada
print(lamp1.ligar_desligar())  #Desligada
# Out:
# Desligada
# lampada ligada
# lampada desligada
#
# False
# True
# teste False
# False

# %% [markdown]
# <hr style="border: 2px solid #4500ff;">
#
# # <font color="#4500ff" style="font-size: 25px;">Exercício 152</font>
# <hr style="border: 2px solid #4500ff;">
#
#  <p style='font-size: 23px; line-height: 2; margin: 0px 0px; text-align: justify; text-indent: 0px;'>
# <i><b> Crie uma classe Lampada com os seguintes atributos e métodos:
#
# ## Atributos:
#
# ### - Cor
#
# ### - Voltagem
#
# ### - Ligada (a lâmpada deve inicializar desligada)
#
# ## Métodos:
#
# ### - Verificar se a lâmpada está ligada/desligada;
#
# ### - Ligar/desligar a lâmpada
#
# ### - Todos os atributos devem ser privados.
#
#
#
# ## crie um objeto da classe Lampada e teste os métodos criados.
# </b></i>
# </p>
#
# ---

# %%
import math

class Vetor:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    def __add__(self, other):
        return Vetor(self.x + other.x, self.y + other.y)
    
    def __sub__(self, other):
        return Vetor(self.x - other.x, self.y - other.y)
    
    def __mul__(self, other):
        return self.x * other.x + self.y * other.y
    
    def __abs__(self):
        return math.sqrt(self.x**2 + self.y**2)
    
    def __eq__(self, other):
        return self.x == other.x and self.y == other.y
    
    def __ne__(self, other):
        return not self.__eq__(other)
    
    def __str__(self):
        return f"({self.x}, {self.y})"

# Criar dois vetores para teste
vetor1 = Vetor(3, 4)
vetor2 = Vetor(1, 2)

# Testar os métodos implementados
print("Soma:", vetor1 + vetor2)
print("Subtração:", vetor1 - vetor2)
print("Produto interno:", vetor1 * vetor2)
print("Norma do vetor 1:", abs(vetor1))
print("Vetor 1 é igual ao vetor 2?", vetor1 == vetor2)
print("Vetor 1 é diferente do vetor 2?", vetor1 != vetor2)
# Out:
# Soma: (4, 6)
# Subtração: (2, 2)
# Produto interno: 11
# Norma do vetor 1: 5.0
# Vetor 1 é igual ao vetor 2? False
# Vetor 1 é diferente do vetor 2? True

# %% [markdown]
# <hr style="border: 2px solid #4500ff;">
#
# # <font color="#4500ff" style="font-size: 25px;">Exercício 153</font>
# <hr style="border: 2px solid #4500ff;">
#
#  <p style='font-size: 23px; line-height: 2; margin: 0px 0px; text-align: justify; text-indent: 0px;'>
# <i><b> Elabore e implemente uma classe Vetor, com 3 dimensões, que possua os métodos:
#
# ### - Soma;
#
# ### - Subtração;
#
# ### - Multiplicação;
#
# ### - Norma;
#
# ### - Igualdade entre dois vetores;
#
# ### - Diferença entre dois vetores.
#
# ## Utilize métodos mágicos em sua implementação. Crie dois objetos da classe Vetor para testar os métodos criados.
# </b></i>
# </p>
#
# ---

# %%
class Vetor:
    def __init__(self, x, y, z):
        self.x = x
        self.y = y
        self.z = z
        
    def __add__(self, other):
        return Vetor(self.x+other.x, self.y + other.y, self.z + other.z)
    
    def __sub__(self, other):
        return Vetor(self.x-other.x, self.y - other.y, self.z - other.z)     
    
    def __mul__(self, other):
        return Vetor(self.x*other.x, self.y * other.y, self.z * other.z)     
    
    def __abs__(self):
        return math.sqrt(self.x**2 + self.y**2 + self.z**2)  
        
    def __eq__(self, other):
        return self.x==other.x and self.y == other.y and self.z == other.z
    
    def __ne__(self, other):
        return not self.__eq__(other) 
    
    def __str__(self):
        return f"({self.x}, {self.y})"    

    
if __name__=='__main__':
    v1=Vetor(1,2,3)
    v2=Vetor(1,1,1)
    v3=Vetor(1,2,3)
    print(f'{v1}+{v2}={v1+v2}')
    print(f'{v1}-{v2}={v1-v2}')
    print(f'{v1}*{v2}={v1*v2}')
    print(v1==v2)
    print(v1==v3)
    print(v1!=v2)
print("Vetor 1 é diferente do vetor 2?", vetor1 != vetor2)
# Out:
# (1, 2)+(1, 1)=(2, 3)
# (1, 2)-(1, 1)=(0, 1)
# (1, 2)*(1, 1)=(1, 2)
# False
# True
# True
# Vetor 1 é diferente do vetor 2? True

# %% [markdown]
# <hr style="border: 2px solid #4500ff;">
#
# # <font color="#4500ff" style="font-size: 25px;">Exercício 154</font>
# <hr style="border: 2px solid #4500ff;">
#
#  <p style='font-size: 23px; line-height: 2; margin: 0px 0px; text-align: justify; text-indent: 0px;'>
# <i><b> Crie uma classe Conta para simular as operações de uma conta corrente. Sua classe deverá ter os seguintes atributos:
#
# ### - Titular;
#
# ### - Saldo (atributo privado).
#
# ## E os seguintes métodos:
#
# ### - Depositar;
#
# ### - Sacar;
#
# ### - Retornar saldo.
#
# ## Crie um objeto da classe Conta e teste o atributos e métodos implementados.
# </b></i>
# </p>
#
# ---

# %%
class Conta:
    def __init__(self, titular, saldo):
        self.titular = titular
        self.saldo = saldo
        
    def Depositar(self, valor_depositar):
         self.saldo += valor_depositar
        
    def Sacar(self, valor_sacar):
        self.saldo -= valor_sacar
        
    def RetonarSaldo(self):
        print(f"O saldo da conta é {self.saldo}")
        
conta_miguel = Conta("Miguel Freire", 5000)


# Testes
conta_miguel.RetonarSaldo()
conta_miguel.Depositar(30)
conta_miguel.Sacar(20)
conta_miguel.RetonarSaldo()
# Out:
# O saldo da conta é 5000
# O saldo da conta é 5010

# %% [markdown]
# <hr style="border: 2px solid #4500ff;">
#
# # <font color="#4500ff" style="font-size: 25px;">Exercício 155</font>
# <hr style="border: 2px solid #4500ff;">
#
#  <p style='font-size: 23px; line-height: 2; margin: 0px 0px; text-align: justify; text-indent: 0px;'>
# <i><b> Na classe Conta, do exercício anterior, incremente os métodos Depositar e Sacar, verificando se o valor inserido é válido. No caso do último método, verifique se há dinheiro suficiente no saldo da conta. Crie objetos para testar a sua implementação.
# </b></i>
# </p>
#
# ---

# %%
class Conta:
    def __init__(self, titular, saldo):
        self.titular = titular
        self.saldo = saldo
        
    def Depositar(self, valor_depositar):
        if isinstance(valor_depositar, (int, float)):  # Verifica se o valor é int ou float
            self.saldo += valor_depositar
        else:
            valor_depositar = float(input("Valor inválido, digite um número! : "))
            self.Depositar(valor_depositar)  # Chamada recursiva usando self.Depositar
        
    def Sacar(self, valor_sacar):
        if self.saldo > valor_sacar:
            if isinstance(valor_sacar, (int, float)):  # Verifica se o valor é int ou float
                self.saldo -= valor_sacar
            else:
                valor_sacar = float(input("Valor inválido, digite um número! : "))
                self.Sacar(valor_sacar)  # Chamada recursiva usando self.Sacar
        else:
            valor_sacar = float(input("Saldo inferior ao valor de saque, defina um novo valor de saque! : "))
            self.Sacar(valor_sacar)  # Chamada recursiva usando self.Sacar            
        
    def RetonarSaldo(self):
        print(f"O saldo da conta é {self.saldo}")
        
conta_miguel = Conta("Miguel Freire", 5000)


# Testes
conta_miguel.RetonarSaldo()
conta_miguel.Depositar("olá")
conta_miguel.Sacar(6000)
conta_miguel.RetonarSaldo()
# Out:
# O saldo da conta é 5000
# Valor inválido, digite um número! : 30
# Saldo inferior ao valor de saque, defina um novo valor de saque! : 20
# O saldo da conta é 5010.0

# %% [markdown]
# <hr style="border: 2px solid #4500ff;">
#
# # <font color="#4500ff" style="font-size: 25px;">Exercício 156</font>
# <hr style="border: 2px solid #4500ff;">
#
#  <p style='font-size: 23px; line-height: 2; margin: 0px 0px; text-align: justify; text-indent: 0px;'>
# <i><b> Faça as seguintes modificações na classe Conta do exercício anterior:
#
# ### ° Crie o método extrato, para registrar e mostrar na tela as operações efetuadas (tipo, valor e data);
# ### ° Crie o método resumo, para mostrar na tela o titular e o saldo da conta.
#
# </b></i>
# </p>
#
# ---

# %%
from datetime import datetime

class Conta:
    
    def __init__(self, titular, saldo):
        self.__titular = titular
        self.__saldo = saldo
        self.___lista_operacoes = []
        
    def Depositar(self, valor_depositar):
        if isinstance(valor_depositar, (int, float)):  # Verifica se o valor é int ou float
            self.__saldo += valor_depositar
            hora_atual = datetime.now().time().strftime("%H:%M:%S")  # Formata para horas:minutos:segundos
            self.___lista_operacoes.append(f'|Depositar| --> Valor: {valor_depositar} // horário: {hora_atual}')
        else:
            valor_depositar = float(input("Valor inválido, digite um número! : "))
            self.Depositar(valor_depositar)  # Chamada recursiva usando self.Depositar
        
    def Sacar(self, valor_sacar):
        if self.__saldo > valor_sacar:
            if isinstance(valor_sacar, (int, float)):  # Verifica se o valor é int ou float
                self.__saldo -= valor_sacar
                hora_atual = datetime.now().time().strftime("%H:%M:%S")  # Formata para horas:minutos:segundos
                self.___lista_operacoes.append(f'|Saque| --> Valor: {valor_sacar} // horário: {hora_atual}')
            else:
                valor_sacar = float(input("Valor inválido, digite um número! : "))
                self.Sacar(valor_sacar)  # Chamada recursiva usando self.Sacar
        else:
            valor_sacar = float(input("Saldo inferior ao valor de saque, defina um novo valor de saque! : "))
            self.Sacar(valor_sacar)  # Chamada recursiva usando self.Sacar            
        
    def RetonarSaldo(self):
        print(f"O saldo da conta é {self.__saldo}")
        
    def Extrato(self):
        print()
        print("*"*int((len(self.___lista_operacoes[-1]))/2), "Extrato", "*"*int((len(self.___lista_operacoes[-1]))/2))
        for i in self.___lista_operacoes:
            print(i)
        print("*"*int((len(self.___lista_operacoes[-1]))/2) + "*"*(len("Extrato")+2) + "*"*int((len(self.___lista_operacoes[-1]))/2))
        
    def resumo(self):
        print(f'Titular: {self.__titular}')
        print(f'Saldo: R$ {self.__saldo}')        
        
conta_miguel = Conta("Miguel Freire", 5000)


# Testes
conta_miguel.RetonarSaldo()
conta_miguel.Depositar("olá")
conta_miguel.Sacar(6000)
conta_miguel.RetonarSaldo()
conta_miguel.Extrato()

print()

conta_miguel.resumo()
# Out:
# O saldo da conta é 5000
# Valor inválido, digite um número! : 30
# Saldo inferior ao valor de saque, defina um novo valor de saque! : 20
# O saldo da conta é 5010.0
#
# ********************** Extrato **********************
# |Depositar| --> Valor: 30.0 // horário: 19:56:12
# |Saque| --> Valor: 20.0 // horário: 19:56:12
# *****************************************************
#
# Titular: Miguel Freire
# Saldo: R$ 5010.0
